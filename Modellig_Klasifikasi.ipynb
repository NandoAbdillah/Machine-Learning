# %%
# Similarity & Disimilarity
# Kesamaan(mirip) dan ketidaksamaan(tidak mirip)
# hal ini banyak diterapkan pada ai zaman sekarang , contohnya pada face recognization
# memeriksa kemiripan satu dokumen dengan dokumne yang lain

# %%
# Modellling sebenarnya ada 3 yaitu -> klasifikasi,prediksi, estimasi
