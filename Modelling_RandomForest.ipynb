# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df = pd.read_csv('./main/Supervised Learning/covid19.csv')
df
# Out:
#    temperatur badan  sesak nafas  batuk  diagnosis sakit covid-19
# 0                 1            1      0                         1
# 1                 0            1      1                         1
# 2                 0            0      0                         0
# 3                 1            0      1                         0
# 4                 1            1      0                         1
# 5                 0            1      0                         1
# 6                 1            1      1                         1
# 7                 0            0      1                         0

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,3]

# %%
x,y
# Out:
# (   temperatur badan  sesak nafas  batuk
#  0                 1            1      0
#  1                 0            1      1
#  2                 0            0      0
#  3                 1            0      1
#  4                 1            1      0
#  5                 0            1      0
#  6                 1            1      1
#  7                 0            0      1,
#  0    1
#  1    1
#  2    0
#  3    0
#  4    1
#  5    1
#  6    1
#  7    0
#  Name: diagnosis sakit covid-19, dtype: int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state =1)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(criterion = 'gini', n_estimators =10)
# entrophy = information gain
# gini = gini index
# n_estimator adalah jumlah 10 pohon
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
y_pred = model.predict(X_test)

# %%
print('Acccuracy: ' , metrics.accuracy_score(y_test,y_pred))
# Out:
# Acccuracy:  1.0
